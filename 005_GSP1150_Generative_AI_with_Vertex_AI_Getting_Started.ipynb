# %% [markdown]
# [Generative AI with Vertex AI: Getting Started](https://www.cloudskillsboost.google/focuses/63250?catalog_rank=%7B%22rank%22%3A2%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23834673)

# %% [markdown]
# Termin "generatywna sztuczna inteligencja" (Generative AI) odnosi się do dziedziny sztucznej inteligencji, która zajmuje się tworzeniem nowych i oryginalnych treści, takich jak obrazy, dźwięki, teksty itp., przy użyciu algorytmów i modeli uczenia maszynowego.
#
# W kontekście Google Cloud Platform (GCP), Generative AI odnosi się do zestawu narzędzi i usług udostępnianych przez GCP, które umożliwiają tworzenie i wykorzystywanie generatywnych modeli sztucznej inteligencji. GCP oferuje różne usługi, które wspierają tworzenie i wdrażanie modeli generatywnych, takie jak AutoML, Cloud AI Platform, TensorFlow, BigQuery i wiele innych.
#
# Przykłady zastosowań Generative AI w GCP obejmują generowanie obrazów, muzyki, tekstu, animacji, tworzenie modeli generatywnych dla projektów artystycznych, interakcję z generatywnymi modelami za pomocą interfejsów API itp.
#
# Generative AI w GCP dostarcza narzędzi i infrastruktury, które umożliwiają badanie i rozwijanie zaawansowanych technik generatywnych w ramach projektów i aplikacji, które wymagają twórczego tworzenia treści przy użyciu sztucznej inteligencji.

# %% [markdown]
# ![2023-05-19 15_36_02-Generatywna sztuczna inteligencja z sztuczną inteligencją wierzchołków_ Pierwsze.png](data:image/png;base64,...)

# %%
# https://ai.google/discover/palm2

# https://cloud.google.com/blog/products/ai-machine-learning/google-cloud-launches-new-ai-models-opens-generative-ai-studio

# https://cloud.google.com/vertex-ai/docs/generative-ai/learn/overview

# %% [markdown]
# ![2023-05-19 15_51_22-Generatywna sztuczna inteligencja z sztuczną inteligencją wierzchołków_ Pierwsze.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-19 15_54_48-Generatywna sztuczna inteligencja z sztuczną inteligencją wierzchołków_ Pierwsze.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-19 15_56_15-Generatywna sztuczna inteligencja z sztuczną inteligencją wierzchołków_ Pierwsze.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-19 15_58_10-Generatywna sztuczna inteligencja z sztuczną inteligencją wierzchołków_ Pierwsze.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-19 16_11_41-intro_prompt… - JupyterLab.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-19 15_59_11-Generatywna sztuczna inteligencja z sztuczną inteligencją wierzchołków_ Pierwsze.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-19 16_15_00-Generatywna sztuczna inteligencja z sztuczną inteligencją wierzchołków_ Pierwsze.png](data:image/png;base64,...)
